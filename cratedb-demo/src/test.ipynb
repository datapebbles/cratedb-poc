# %%
from PIL import Image

# %%
# %run search.py
# Out:
# What are you looking for?
# white shoe with gold print
# ['/Users/abdulks/Documents/code/cratedb_demo/datasets/processed//17711.jpg']

# %%
Image.open('/Users/abdulks/Documents/code/cratedb_demo/datasets/processed//17711.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=60x80>
